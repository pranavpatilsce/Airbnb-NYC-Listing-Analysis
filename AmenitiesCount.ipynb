# %%
# from collections import Counter
# import pandas as pd
# import nltk

# top_N = 1000

# df = pd.read_csv(r'listings_cleaned_two_initial_amenities.csv', low_memory=False)

# stopwords = nltk.corpus.stopwords.words('english')
# # RegEx for stopwords
# #RE_stopwords = r'\b(?:{})\b'.format('|'.join(stopwords))
# # replace '|'-->' ' and drop all stopwords
# #words = (df.str.lower())
# '''
#            .replace([r'\|', RE_stopwords], [' ', ''], regex=True)
#            .str.cat(sep=' ')
#            .split()
# )
# '''
# # generate DF out of Counter
# rslt = pd.DataFrame(Counter(df).most_common(top_N),
#                     columns=['Word', 'Frequency']).set_index('Word')
# print(rslt)

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

top_N = 1000

df = pd.read_csv(r'listings_cleaned_two_initial_amenities.csv', low_memory=False, header=None)
pd.set_option('display.max_columns', None, 'display.max_rows', None)

#s = 0
#for i in range(0, 1):
g = df.groupby(22)
g = g[22].count()
g


#df['Internet'].nunique()
# for i in range(0, 1):
#     g = df.sort_values(by=[i], ascending=True)
#     g = df.groupby(i).count()

# g
# Out:
# 22
# 24-hour check-in                                 61
# Accessible-height bed                            16
# Accessible-height bed}                            4
# Accessible-height toilet                          7
# BBQ grill                                        19
# BBQ grill}                                        1
# Baby bath                                        32
# Baby monitor                                     12
# Babysitter recommendations                       54
# Bathtub                                         366
# Bathtub with bath chair                           1
# Bathtub with bath chair}                          2
# Bathtub}                                          8
# Beach essentials                                  6
# Beach essentials}                                 1
# Beachfront}                                       3
# Bed linens                                      951
# Bed linens}                                      13
# ...
